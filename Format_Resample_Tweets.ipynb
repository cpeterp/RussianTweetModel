# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Bring in the datasets (Note: `pol_tweet_data` and `troll_tweet_data` are very large)

# %%
pol_tweet_data = pd.read_csv('./datasets_large/politician-tweets/pol_tweets.csv', sep=';')

# %%
troll_tweet_data = pd.read_csv('./datasets_large/russian-troll-tweets/combined.csv',
                               dtype={'external_author_id': str, 'author':str, 'content':str, 'region': str, 
                                      'language': str, 'publish_date':str, 'harvested_date':str, 'following':int, 
                                      'followers':int, 'post_type':str, 'account_type':str, 'retweet':bool, 
                                      'account_category':str, 'new_june_2018':bool, 'alt_external_id':str, 
                                      'tweet_id': str, 'article_url': str, 'tco1_step1':str, 'tco2_step1':str, 
                                      'tco3_step1': str })

# %%
news_tweet_data = pd.read_csv("./datasets_large/news-tweets/news_tweets.csv", sep=";",
                          dtype={'tweet_id':str, 'author_id':str, 'publish_date':str, 
                                'content':str, 'link_url':str, 'account_category':str, 
                                'author':str, 'account_type':str})

# %%
pol_authors = pd.read_csv("./datasets_large/politician-tweets/pol_accounts.csv", sep=";")

# %%
print("Troll tweets size:", troll_tweet_data.shape)
print("Politician tweets size: ", pol_tweet_data.shape)
print("News tweets size:", news_tweet_data.shape)
# Out:
# Troll tweets size: (2946207, 21)
# Politician tweets size:  (1661553, 10)
# News tweets size: (41772, 8)

# %% [markdown]
# Need to downsample the troll and politician tweets for efficency and to reduce class imbalance later on.

# %%
# Down sample number of tweets because there are so many more than news tweets
# This improves efficency for processing and will help prevent class imbalances in our model
troll_tweet_data = troll_tweet_data.sample(n=200000, random_state=42)
pol_tweet_data = pol_tweet_data.sample(n=200000, random_state=42)

# %% [markdown]
# Now we need to drop some of the features and rename others. Since the News Tweets have already been formatted, we'll use that as a template.

# %%
news_tweet_data.columns
# Out:
# Index(['tweet_id', 'author_id', 'publish_date', 'content', 'link_url',
#        'account_category', 'author', 'account_type'],
#       dtype='object')

# %%
troll_tweet_data.columns
# Out:
# Index(['external_author_id', 'author', 'content', 'region', 'language',
#        'publish_date', 'harvested_date', 'following', 'followers', 'updates',
#        'post_type', 'account_type', 'retweet', 'account_category',
#        'new_june_2018', 'alt_external_id', 'tweet_id', 'article_url',
#        'tco1_step1', 'tco2_step1', 'tco3_step1'],
#       dtype='object')

# %%
pol_tweet_data.columns
# Out:
# Index(['id', 'user_id', 'created_at', 'tweet_text', 'hashtag_entities',
#        'url_entities', 'favorites_count', 'retweet_count', 'quoted_status_id',
#        'in_reply_to_status_id'],
#       dtype='object')

# %%
troll_tweet_data.drop(['region', 'language','harvested_date', 'following', 'followers',
                       'updates', 'new_june_2018', 'alt_external_id','tco1_step1', 
                       'tco2_step1', 'tco3_step1', 'retweet', 'post_type', 'article_url'],
                      axis=1, inplace=True)

# %%
pol_tweet_data.drop(['hashtag_entities','favorites_count', 'retweet_count', 
                     'quoted_status_id','in_reply_to_status_id', 'url_entities'],
                   axis=1, inplace=True)

# %%
troll_tweet_data.rename(index=str, columns={'external_author_id':'author_id', 'article_url':'link_url'}, inplace=True)

# %%
pol_tweet_data.rename(index=str, columns={'id':'tweet_id', 'user_id':'author_id', 
                                          'created_at':'publish_date', 'tweet_text':'content', 
                                          'url_entities':'link_url'}, inplace=True)

# %%
print("News Tweets Columns:", news_tweet_data.columns)
print("Troll Tweets Columns:", troll_tweet_data.columns)
print("Politician Tweets Columns:", pol_tweet_data.columns)
# Out:
# News Tweets Columns: Index(['tweet_id', 'author_id', 'publish_date', 'content', 'link_url',
#        'account_category', 'author', 'account_type'],
#       dtype='object')
# Troll Tweets Columns: Index(['author_id', 'author', 'content', 'publish_date', 'account_type',
#        'account_category', 'tweet_id'],
#       dtype='object')
# Politician Tweets Columns: Index(['tweet_id', 'author_id', 'publish_date', 'content'], dtype='object')

# %% [markdown]
# Need to do some feature engineering and deal with useless data. For the `troll_tweet_data`, I want only the tweets from trolls (the dataset included tweets from authors not linked to Russian troll groups such as non-Russian accounts, meme pages, paid news). We will drop everything from that dataset that isnt a troll. We will also rename the category to get rid of their leaning in the `account_category` feature to simplify categorization. Their leaning will be included in the `account_type` feature.
#
# For the polician tweets, we need to grab the author handles and their political lean from the author dataframe. We also set the category to politician.
#
# For all three dataframes, we will remove non-english tweets. These also include tweets with nothing but emojis or urls.

# %%
troll_tweet_data.loc[troll_tweet_data['account_category'] == "RightTroll", 'account_category'] = "Troll"
troll_tweet_data.loc[troll_tweet_data['account_category'] == "LeftTroll", 'account_category'] = "Troll"

# %%
troll_tweet_data['account_category'].value_counts()
# Out:
# Troll           77171
# NonEnglish      55706
# NewsFeed        40999
# HashtagGamer    16308
# Commercial       8167
# Unknown           885
# Fearmonger        764
# Name: account_category, dtype: int64

# %%
troll_tweet_data = troll_tweet_data.loc[troll_tweet_data['account_category'] == "Troll"]

# %%
pol_tweet_data["account_category"] = "Politician"

# %%
# Get the handle name from the authors dataframe
def grab_authors(x):
    return(pol_authors.loc[pol_authors['id'] == x['author_id'],'screen_name'].values[0])

# %%
# Grab the political stance from the authors dataframe
def grab_party(x):
    if "democrat" in pol_authors.loc[pol_authors['id'] == x['author_id'],'array_agg'].values[0].lower():
        return("Left")
    elif "republican" in pol_authors.loc[pol_authors['id'] == x['author_id'],'array_agg'].values[0].lower():
        return("Right")
    else:
        return("Other")

# %%
# Need to fill in author and account type (left, right), for political tweets
pol_tweet_data['author'] = pol_tweet_data.apply(grab_authors, axis=1)

# %%
pol_tweet_data['account_type'] = pol_tweet_data.apply(grab_party, axis=1)

# %%
#all_tweet_data = pd.concat([pol_tweet_data, troll_tweet_data], sort=False)

# %%
#news_tweet_data = pd.read_csv('datasets/news-tweets/news_tweets.csv', sep=';')
#all_tweet_data = pd.concat([all_tweet_data, news_tweet_data], sort=False)

# %%
#all_tweet_data.to_csv('datasets/modified_data/combined_tweets.csv', index=False, sep=";")

# %%
# Need to drop non-english
from langdetect import detect
def detect_english(text):
    try:
        lang = detect(text)
    except:
        lang = "None"
        #print(text)
    
    if lang == "en":
        return(1)
    else:
        return(0)

# %%
news_tweet_data['is_eng'] = news_tweet_data.content.apply(detect_english)
news_tweet_data = news_tweet_data.loc[news_tweet_data.is_eng == 1]
# Out:
# https://t.co/r4Crcskcgv
# https://t.co/rPUUe0WPZT
# https://t.co/wcEDpmYHev
# https://t.co/WffaKBJldo
# https://t.co/61Zi9imHEf
# https://t.co/PVfkMzJQYm
# https://t.co/ZZGFozXXE6
# https://t.co/hYFFJctpd4
# https://t.co/6TNKIuMNYi
# https://t.co/BDe3IihErD
# https://t.co/rTD8HHu3YS
# https://t.co/mZf8bcKCNN
# https://t.co/1Ab0b25clS
# https://t.co/ZFRjXY913h
# 😏 https://t.co/ZLpSWDtfUn
# 🔥🔥🔥 https://t.co/m8KRDiiyZl
# https://t.co/jwi56YIpwt https://t.co/zVYBUEmt63
# 🤫
# https://t.co/ivXQVRb3TB
# https://t.co/D8iCUWFUyF https://t.co/Zprd6a4Lvw
# 😢 https://t.co/oeKF4FLzeT
# https://t.co/sKfXgIe96y
# https://t.co/jsLrVcusQr
# https://t.co/2El6yFErcO
# https://t.co/0U1gFBYrSO
# https://t.co/RlsymtfwaA
# https://t.co/KPMw1nn6cw
# https://t.co/G2jzigT7rH
# https://t.co/Gw6qxBscoJ
# https://t.co/iDAaxMDrvW
# https://t.co/6D0ptaxVMN
# 🏆 🏆 🏆  https://t.co/G4eeWOnsO4
# https://t.co/6DXdhl57zS
# https://t.co/gQKhpyNRdO
# https://t.co/goZwJFA6wU
# https://t.co/hJrDAQqsuY
# https://t.co/w3IgCuIBat
# https://t.co/zD8nmQI2ez
# https://t.co/MxRwhxcwX3
# https://t.co/pYpjx1cVvt
# https://t.co/kGfkax5LNC
# https://t.co/lO0immsCm7
# https://t.co/6l2i5rZTQq
# https://t.co/POapXtj5kw
# https://t.co/iU9EjJdy5m
# https://t.co/jPNldXdbLI
# https://t.co/FMU9e8Vgxt
# https://t.co/XOnx3GwBHF
# https://t.co/Q8ryorCN9c
# https://t.co/QPNcx0T46K
# https://t.co/Y61jOHtpLk
# https://t.co/y77HNQStkZ
# https://t.co/1YVo2Zy2GM
# https://t.co/g5jLFWrwL0
# 🤷 https://t.co/6umJD880IJ
# 😱 https://t.co/FaKEMM39SQ
# https://t.co/w9lbEg5Swx
# https://t.co/rXHoDOznTn
# https://t.co/FImqoxJUQ4
# https://t.co/XOnx3GwBHF
# https://t.co/Psq8U4QjAC
# https://t.co/6R63dGYcKM
# https://t.co/DBE14rxqtR
# https://t.co/CO7Oq1fURX
# https://t.co/UwIbvuF8qn
# https://t.co/pjp3kKLta1
# https://t.co/V1bFC5QwiB
# https://t.co/lSYfwGti3g
# https://t.co/zD8nmQI2ez
# https://t.co/mn1VX7GMC0
# https://t.co/WKs7bim9hC
# https://t.co/BK7pX0RrtP
# https://t.co/v3hZ1vvRh4
# https://t.co/PtnqP29s20
# https://t.co/gP6oIocOco
# https://t.co/oKbFVeSvmG
# https://t.co/k0DZBsujIQ
# https://t.co/kGfkax5LNC
# https://t.co/TUADAGOfxT
# https://t.co/lj9pWrzG9N
# https://t.co/MBOaXlFDYD
# https://t.co/CHylO8cVi2
# https://t.co/R7LxXxGFXn
# https://t.co/61F37Nlo11
# https://t.co/JssjnwgCtW
# https://t.co/lNBEZWg2LK
# https://t.co/BPRGF7Ibnl
# https://t.co/aOmon5etmP
# https://t.co/SudQp7uOdP
# https://t.co/AFdzZyKrvB
# https://t.co/sbPVRjhTk4
# https://t.co/ZBhJysWXCZ
# 💔😢 https://t.co/aLy3toyhX5
# https://t.co/61F37Nlo11
# https://t.co/TtuiEBrHyp
# https://t.co/U4Gu3NISj4
# https://t.co/BK7pX0RrtP
# https://t.co/j339JHvpfS
# https://t.co/WKs7bim9hC
# https://t.co/MBOaXlFDYD
# https://t.co/HT1zPnjC6o
# https://t.co/MTTs9VA4wC
# https://t.co/ta4PF35P3K
# https://t.co/ftz4NLz8m6
# https://t.co/dS0ftd30gw
# https://t.co/JejKqQbkMV
# https://t.co/EDY7KEz0pp
# https://t.co/nibD9K4d3m
# https://t.co/37eZlwB6bQ
# https://t.co/6iM5mNxI2h
# https://t.co/6CLG5zR4aP
# https://t.co/6zs2jSjh5b
# https://t.co/HWK1jJrcEP
# https://t.co/UCA7jwLaD4
# https://t.co/rdglC32IbX
# https://t.co/2IlX5dtI4b
# https://t.co/h8D1P8sG8i
# https://t.co/q4I3QwBhI9
# https://t.co/lN90eyz4wJ
# https://t.co/vH1UGJ43jh
# https://t.co/ovXySogNJF
# https://t.co/i2BtatNQX9
# https://t.co/rPxRnBLlAc
# https://t.co/bmKkmcPDzN
# https://t.co/KxdkSXDVIq
# https://t.co/9i9PnpDZ7F
# https://t.co/bznJUkatOO
# https://t.co/zonPGxJa4P
# https://t.co/Ax3WUYia0W
# https://t.co/ShShB7hVig
# https://t.co/ejBD7VSKwg
# https://t.co/5q7GYPzqcW
# https://t.co/T8Vj8qxBhi
# https://t.co/tZZpqGFC5W
# https://t.co/Z2znS0h26o
# https://t.co/nAAKWUg9SA
# https://t.co/k5YwgVo1W9
# 😱 https://t.co/AGBKs99yn6
# 🙄 https://t.co/U2uQHDU8Th
# https://t.co/AzQ9gG4eKT
# https://t.co/ta4PF35P3K
# https://t.co/aKGL1J5yBb
# https://t.co/rdglC32IbX
# https://t.co/qrOVWDTTDO
# https://t.co/tNxaXHPs2k
# https://t.co/h5zSGb060Q
# https://t.co/20dyr9y5Wc
# https://t.co/lr0xsMnWFG

# %%
troll_tweet_data['is_eng'] = troll_tweet_data.content.apply(detect_english)
troll_tweet_data = troll_tweet_data.loc[troll_tweet_data.is_eng == 1]
# Out:
# https://t.co/SKZOJos6C4
# https://t.co/FB0e6ZQeDX
# 💯💯 https://t.co/cTUKrwzirz
# https://t.co/BeFjQsJnQ6
# http://t.co/TQI3VboOKN
# https://t.co/jDtYx9h9oT
# https://t.co/pRiPpsc5hZ
# https://t.co/Le1ZRH80Bd
# https://t.co/Bv9PjCezJK
# https://t.co/aLxCVIfR2m
# https://t.co/QWAWSQ071D
# https://t.co/Zvhj8kXNFD
# !! https://t.co/foO1ttyDjH
# https://t.co/GzIGOYu6VV
# https://t.co/pSR5Iabfnc
# https://t.co/KMP8gc1Z1i
# https://t.co/VSlI8clmwm
# https://t.co/SB5Qf1qRCA
# https://t.co/h86L0Pci7p
# 58. https://t.co/Cz3MO5idbK
# https://t.co/gCUC2jKwa1
# https://t.co/NZ0QlLz2x6
# https://t.co/mcnZAJzQs1
# https://t.co/2DQLQlLuwy
# https://t.co/cFmvwAE7Pk
# https://t.co/2Vpz207nXB https://t.co/q4qXxrAej4
# https://t.co/KRTU5rirXS
# https://t.co/KqM77ahhEN https://t.co/DHNdUuRMs7
# https://t.co/uiK8TcHtjK
# https://t.co/3iHYp4FG4J
# https://t.co/8StRWRpv2M
# https://t.co/zuIzbpejyw
# https://t.co/6GSxBbIAGs
# https://t.co/H93WoEnv4D
# https://t.co/h4IJw703xt
# https://t.co/8aJUZkCH1V
# https://t.co/KhE3g0tp2P
# https://t.co/WylTJVXtuI
# https://t.co/mFI9B57kCi
# https://t.co/ZzaBRXvYRX
# https://t.co/h3gSmp9eal
# https://t.co/nAbfMaUqC4
# https://t.co/MokVbo0JeF
# https://t.co/u4ozLqZT9c
# 😭😭😭😭😭😭 https://t.co/NQEszbi7FZ
# https://t.co/FzUcINr0mg
# https://t.co/gh0nAKsdB8
# https://t.co/yTVXwiBTdb
# ??? https://t.co/mfMH1aJGav
# https://t.co/DSTiOFppYK
# https://t.co/CAto71NUPf
# https://t.co/u36XpVwIHj
# .@hughhewitt .@POTUS .@tuckercarlson .@seanhannity https://t.co/vKkY10ei43
# https://t.co/yCbz8MQbMj
# https://t.co/1O0qqJIbsH
# https://t.co/h04C2n1Igt
# https://t.co/9Mh7QE4zch
# https://t.co/UpL6f7XvwF
# https://t.co/gwWwqwyIII
# https://t.co/Cl8V2Vtavf
# https://t.co/v4xAwkrUsu
# https://t.co/36kjeV1Sf2
# https://t.co/rk3BuHeBVP
# https://t.co/3byDTLmvJP
# https://t.co/OHHGmHOTm3
# 😂😂😂😂😂 https://t.co/AiLxLMMggD
# https://t.co/9PShHDJGsS
# https://t.co/6oi3x1y3Pu
# https://t.co/kxuU1gFB8u
# https://t.co/9oUqCoRwvF
# ❤️❤️https://t.co/EZkWnwoBpS
# https://t.co/Wfw9DmBYLZ
# https://t.co/XUs0MAspai
# https://t.co/t3ChVCit24
# https://t.co/TsUmLGVrac  🎙🔥🎙🔥🎙🔥🎙🔥🎙🔥🎙🔥🎙 https://t.co/vcdKyQ6WuS
# 😐 https://t.co/AHRLXDeXF7
# https://t.co/fjcZCSyai2
# https://t.co/VSxjvxDKO1
# https://t.co/ZGErGy0dMx
# https://t.co/TLXyfc3yKq
# https://t.co/DIUqKf6qWv
# https://t.co/ARXAslmDTa
# https://t.co/nUOosQ97nD
# http://t.co/Clc6eMsHZI
# https://t.co/hob7gZbenj
# https://t.co/A5Ku8wonLz
# https://t.co/dI6sHgwkBr
# https://t.co/ssDY99otrN
# https://t.co/HZAVANJwSV
# https://t.co/MRbJpa6QNQ
# https://t.co/paF0bnEii6
# ☺️ https://t.co/07TBgeqgdK
# https://t.co/KqM77ahhEN https://t.co/DHNdUuRMs7
# https://t.co/q9t4UZEAcN
# !!! https://t.co/LSzALJMeUn
# https://t.co/VTqeH8Uaws
# https://t.co/yxo0v0SQrw
# https://t.co/OU43ybpA3c
# https://t.co/USkcC3dtCe
# https://t.co/Ww2Jf7oOCi
# https://t.co/2o6n7MezpE
# https://t.co/g76WS3JXq3
# 😃👍 https://t.co/MPpRZ685OI
# ...... https://t.co/TzsxVyeEMB
# https://t.co/kXFHlbqySV
# https://t.co/Shj4YjEhdH
# https://t.co/6gdbm7ySdM
# https://t.co/XLV0sQxqx2
# https://t.co/cKGK2q9Ivl
# https://t.co/tfdts8huUF
# https://t.co/Cb03DgwBNq
# RT ByeByeObama1: #MAGA #USA 🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸… https://t.co/kQWeRb7ujD
# https://t.co/V03c1ey6uD
# https://t.co/ONO2n62Juf
# https://t.co/6VwizcywsW https://t.co/nz1xJ33E1W
# https://t.co/KM38BzwvgU
# https://t.co/0wAjs274EX
# https://t.co/2yWUmxbJhi
# 2017. https://t.co/yV7B5Z8rz6
# https://t.co/CI5lQd7NSp https://t.co/qvWyjW5yPY
# https://t.co/XYVtUK01CP
# https://t.co/QDxUllPWNv
# https://t.co/XDnv9Q2d1r
# https://t.co/YBGgpYs2Sv
# https://t.co/sHv33xjs8c
# https://t.co/n3X5EPfmW9
# https://t.co/lv9syNPlnl
# https://t.co/j3ntIwAyvZ
# https://t.co/gAAIjCWYa3
# https://t.co/KPbHmS1nuk
# https://t.co/NQSdK2UyvI https://t.co/KHJgLclIMG
# https://t.co/BAUlWbyTUc
# http://t.co/qOIVzFESrc
# https://t.co/FyRVZ52ACk
# 😤😤😤 https://t.co/kXjBHKz6xM
# https://t.co/oqYjyWtspZ
# https://t.co/A6JJ0YnyFp
# https://t.co/OJcXFr3siq
# https://t.co/41JYRTSBw8
# https://t.co/dPf1YTywql
# ☺️ https://t.co/b14ZlyVsR7
# https://t.co/fKRTqD8Nd8
# . https://t.co/dhD3YB0pJ2
# https://t.co/NYlTstsEiC
# https://t.co/QqnhaECtI5
# https://t.co/mcJIsOVQ3M
# https://t.co/h3gSmp9eal
# https://t.co/eSGYAYUecC
# https://t.co/9C2cd4E7Zh
# https://t.co/hob7gZbenj
# https://t.co/qhblJ9kcXM
# https://t.co/4tvqLCkFBM
# https://t.co/0RxxAhvXeD
# https://t.co/SqkWIHRIfF
# https://t.co/RTuboLHl8x
# https://t.co/h3gSmp9eal
# https://t.co/xzmOV3L3zU
# 28. https://t.co/emGwe9eStv
# 😂 https://t.co/9kSwmgqoiI
# https://t.co/TXikOmTobX
# https://t.co/J0riEyoTgW
# https://t.co/u11s7EWt06
# https://t.co/aGaOYqd9ZU
# https://t.co/5XjnkjszeR
# https://t.co/FMao0uJis7
# 😅😅😅 https://t.co/bN6QsWKhwo
# https://t.co/h3gSmp9eal
# https://t.co/041oxVcrbw
# https://t.co/MHzv7X5kqR
# https://t.co/aaYfj8ABUt
# ❤️️❤️️❤️️❤️️❤️️❤️️ https://t.co/96tYuDUprq
# https://t.co/Cey7YIMNMh
# https://t.co/cU3FpOCDca
# https://t.co/ZPte7nIetV
# https://t.co/hz6yIloooW
# https://t.co/FC2iukk8So
# https://t.co/rKP6qWxPJ7
# https://t.co/lWpuGrJuFm
# https://t.co/9RTo1r3CgE
# 1,000,000.00
# https://t.co/EeWfYfErJq
# https://t.co/jc4lpW2Y8R
# https://t.co/Mb6gXlz7QS https://t.co/khMEFj4zGD
# https://t.co/ljNiByil2y
# ..... https://t.co/JEIPDTXncw
# https://t.co/k02g5DleX0 https://t.co/dRiGqpShhp
# ........ https://t.co/IIYpUQmbWl
# https://t.co/r2olZFS2ts
# https://t.co/2Lkzo1cdwr
# https://t.co/tei12DTXsK
# https://t.co/C8a03QTfdy
# https://t.co/2aPMQ4zy8l
# https://t.co/fhnsi50BrJ
# https://t.co/0V42QwdShi
# http://t.co/dRAI3wBElK
# https://t.co/ATpKwkhzD4
# 😂😂😂😂 https://t.co/qXdyy9vIXr
# https://t.co/mdLmxop8JW https://t.co/QxEZVpOzGZ
# https://t.co/xAq09B3vRd
# https://t.co/4I7T0G3GTq
# https://t.co/1Q64klBrhU
# https://t.co/Ij0ut5HXDL
# .@realDonaldTrump https://t.co/44kdx2t4V0
# http://t.co/He3S2WW6Yu
# https://t.co/SYqVcf2gXJ
# https://t.co/B4GhwXvny7
# https://t.co/hMt7nPN59W
# https://t.co/SiDUq6jFcW
# https://t.co/yBokgF2oM5
# https://t.co/xYe0WpMHjZ
# https://t.co/lsrhNUB57B
# Hillary is a giant piece of 💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩💩#280characters https://t.co/0IA93DG4i9
# https://t.co/uG4AHDRsnF https://t.co/BOqbajQgNV
# ✊🏾 https://t.co/DsLxI96ZVG
# https://t.co/hWF3C1xgLb
# https://t.co/zIOSiTFKFf
# https://t.co/5XgBFIQlK4
# https://t.co/xbzhKu2ZlM
# https://t.co/x1DzZna9eA https://t.co/IF0ElNBGoq
# https://t.co/O7OIfAmQYZ
# https://t.co/OOwg5bZrVU
# 🤔🤔 https://t.co/EJrw0LjqSz
# https://t.co/iN0daJ6nst
# .🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸 https://t.co/uJSDYOxPwg
# https://t.co/1nH9oWqh5p
# https://t.co/ZGErGy0dMx
# https://t.co/JL80o37Tan
# https://t.co/XJ0uodHWkC
# https://t.co/FiOBMW3aIi https://t.co/Wz5YuxpfEW
# 😂😂😂😂 https://t.co/lV5vQbyLrB
# https://t.co/tieixiS4fT
# https://t.co/32M1gvOQgz
# https://t.co/o4vb5tASE8
# https://t.co/4Eig4PjxIP
# https://t.co/VSExXvnoiA
# https://t.co/RYosnTI6Sm
# https://t.co/iciTdY759O
# https://t.co/iiaujZACEf
# https://t.co/aodZ3woVmD
# 🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣 https://t.co/hT8VfwH3r1
# https://t.co/SlxJKyh44L
# https://t.co/hZaupPcFXs
# https://t.co/meUK1GNdGA
# https://t.co/60DjiIGwG2
# https://t.co/oRJucwyvoG
# 1.60!

# %%
pol_tweet_data['is_eng'] = pol_tweet_data.content.apply(detect_english)
pol_tweet_data = pol_tweet_data.loc[pol_tweet_data.is_eng == 1]
# Out:
# https://t.co/3tl3y5e2MP
# https://t.co/b3i0Bxcb9V
# https://t.co/C7GK4fPKqy
# https://t.co/57nTo4Hi8i
# https://t.co/x3J4WDMKn2
# http://bit.ly/cRTlV9
# https://t.co/dccfuwYIHS
# http://fb.me/AuzqP3gs
# http://t.co/7GPS7l6aC2 http://t.co/w5I3nZqQZi
# http://t.co/JXJgJ2Fech http://t.co/1aWPM8Ak7J
# https://t.co/R4nslZgxsp
# https://t.co/zIwDcASYQo
# https://t.co/r8bwIevEdr https://t.co/fL5sRIrkQs
# http://t.co/VEtShOUATm http://t.co/EJy6orzoUF
#  https://t.co/IvWFN6a0r4
# http://t.co/NJ77jpMG
# https://t.co/LOMoSOMJQV
# https://t.co/KNmkm6y1P2
# [?]?
# https://t.co/bTSpws5IF7
# https://t.co/8KuRPDI0Gi
# https://t.co/CvEEy6saem
# http://fb.me/x0ijmc6d
# https://t.co/3QcRQSlYPg
# http://t.co/5NGaHDdS
# huhhh@kjzzphoenixwgH
# https://t.co/TLWkR26DUx
# http://fb.me/uc0eMvpg
# https://t.co/inVvS0NcVd
# http://t.co/UqjfxGiK http://t.co/hjaXDwTG
# http://t.co/6vjWL0Up http://t.co/ZCEQ5tzU
# https://t.co/OwjjdGvtWy
# http://fb.me/Qk6xSne2
# https://t.co/HxWpoGzDxq
# https://t.co/EHnBWBDEuX
# https://t.co/97RunK9HV2
# https://t.co/ZDxhIIkxNe
# http://fb.me/VkdkuGb3
# https://t.co/mEuzP9IsGD
# https://t.co/U5vv7p0Naa
# http://t.co/RXlzaYiHNL
# https://t.co/yXvuAhX7eJ
# http://t.co/LldSF5tV3N
# http://fb.me/MLI2jtoC
# http://poe.house.gov/News/DocumentSingle.aspx?DocumentID=249413 http://fb.me/YUKvB6mO
# https://t.co/2toTr7Pd5y
# http://t.co/QdYZJTI173
# https://t.co/6J2H4lkHUR
# http://t.co/fdHrIXiA... http://t.co/UZxIx0tt
# https://t.co/ke03fzZvcg
# http://t.co/k2neN3Vu7L
# http://t.co/GmUBfndi
# http://t.co/w0QOvSLYu6
# https://t.co/KFojhc4BOK
#  https://t.co/KNIBTBaVcG
# http://t.co/Pr6TdUWMkX
# https://t.co/eKFENqSlDQ
# https://t.co/RUWykKo9h5
# https://t.co/tuLvqO3ZkB
# https://t.co/h7kR13RXAv
# https://t.co/EIKpqeXpCF
# https://t.co/vP62hcp6cO
# http://twitpic.com/2dtvje
# https://t.co/p3puLDqnfI
# http://www.salisburypost.com/Opinion/061609-edit-burr-comments
# http://journalstar.com/news/local/govt-and-politics/article_fe614c98-eb70-11df-a650-001cc4c002e0.html http://fb.me/Ld3rdd5t
# http://twitpic.com/2a5paj
# http://t.co/AoybiRiQtw
# http://t.co/8EYKWuQQ
# http://t.co/1AtpxNMD
# http://t.co/EwQjEpg6 http://t.co/KpZdJrTN
# https://t.co/tzfQ0saFuI
# https://t.co/0JIqdrH9rr
# https://t.co/GoJoAi05gI
# http://t.co/R8vQSHmB6F
# https://t.co/79g9z0ka2K
# https://t.co/yWJ5nTjoA8
# http://bit.ly/cbARbr
# http://t.co/tSth8EqfbA http://t.co/17S10kmu1o
#  https://t.co/3kZ3l0uHfq
# https://t.co/4oR0srDF30
# https://t.co/tnerRKD1Lj
# http://t.co/CVdP2UAnhw
# https://t.co/nb86xYwtPR
# http://bit.ly/cD3IvX
# https://t.co/VI5ZPcpW79
# http://t.co/7G4DEzzidr
#  https://t.co/3q3inUevVe
# http://t.co/ZwrPiAFd
# http://t.co/hEJBW8zOOt
# https://t.co/r8bwIevEdr https://t.co/acXAzUZlwV
# https://t.co/U3Ku90h686
# https://t.co/Gx2jWyTbWH
# https://t.co/I045NGRlnh
# http://t.co/QywvHJC86T
# http://t.co/OBxLcMEM http://t.co/jxPDglA3
# http://t.co/hk03g1mI
# https://t.co/HczQbTdPF9
# https://t.co/5jwdKFvKo9
# https://t.co/P2gek9UQLA
# https://t.co/BpB4EpCM4W
# http://bit.ly/cOoqwZ
# https://t.co/o90GB3wGUG
# http://www.youtube.com/watch?v=yVQGx-66LJc http://fb.me/RicAgToF
# http://t.co/4X3yLIx7 http://t.co/qj3r7l3T
# http://t.co/pvyG4SSh http://t.co/hHkXLKRK
#  https://t.co/izEJPGCwiq
# https://t.co/7vde282ZOj
# https://t.co/D6VWFzZkd9
# https://t.co/JC6jozAdsA
# https://t.co/kSrDRbDbQn
# https://t.co/eq9YsQkdTF
# https://t.co/8FdgS2i7BQ
# https://t.co/rPZ1CblA1a
# https://t.co/QAR5eUSSvF
# https://t.co/JYXNbQ4eMT
# http://t.co/NO5xPPhlfK
# https://t.co/dJ0h9GdWQ0
# http://www.youtube.com/watch?v=ecZC39snQ3E http://fb.me/DgTsNey8
# http://t.co/sNeo9U1E http://t.co/Cv0zgSiu
# http://t.co/pDX0YYwJ04
# https://t.co/QqlBLniCZ6
# http://t.co/WHM6HYQ4
# https://t.co/yS4LwWMwfj
# https://t.co/784MgUFZhA
# http://t.co/dZLH6nJgt4
# http://t.co/C9bP6XrCC4
# https://t.co/2MnW6e1FIp
# http://t.co/WOhGu7lmqg
# https://t.co/uoi3KfeImb
# http://t.co/9KsxKrSW
# https://t.co/5dQ44ckp2F
# https://t.co/eQXrWyxk7c
# http://fb.me/Rw2ooZiL
# https://t.co/QnI34sKJT8
# https://t.co/NujgpGFtp7
# http://yfrog.com/h0q08pwj
# http://t.co/kzasqmLa94
# .@ColinDabritz https://t.co/fiKaQ82kF9
# https://t.co/RQQvANcslF
# https://t.co/BDcZx682Cy
#  https://t.co/C97C1YQZlK
# https://t.co/GAaXDdTciP
#  https://t.co/W5dGM8JMkj
# https://t.co/e4Y4Tf1jjJ
# http://www.youtube.com/watch?v=jgZP8QOybVI&feature=channel_video_title http://fb.me/X2PwLL3y
# https://t.co/m7IawgMEIT
# http://t.co/0rPZFMnqlF
# http://t.co/I7fsOM1r
# http://t.co/QCipRrXyQV
# https://t.co/Z1G22dmU0C
# http://t.co/CkEdpNO5yn
# http://t.co/BjQVGYye3j
# https://t.co/gcYHugatir
# http://t.co/SrGFgQEz
# https://t.co/lLlTElzcoq
# https://t.co/JAIJtZUNZ5
# https://t.co/Erd956jYDz
# https://t.co/VJ1ZKTAzFp
# http://yfrog.com/h079388078j
# http://t.co/Em9sf9DP3Q
# https://t.co/qwMHLSqk9y
# https://t.co/UdPZrz1ylx
# http://www.speaker.gov/Blog/?postid=227596 http://fb.me/wXlbovTp
# http://t.co/f4jkYpILfH
# http://t.co/nHuh8tLfG9 http://t.co/UpNyewioQQ
# https://t.co/aHu5DraoNN
# http://fb.me/Ns2s4aTF
# http://t.co/gy9vIMGNou... http://t.co/fzfqrSBPCX
# https://t.co/HNe5stpq3n
# http://poe.house.gov/News/DocumentSingle.aspx?DocumentID=252825 http://fb.me/GO3JSVUM
# https://t.co/4uezh40Jt0
# https://t.co/HAeRJS1NhY
#  https://t.co/UEghldDxCm
# http://fb.me/SV6u7mR3
# https://t.co/QgpuacqWmx
# https://t.co/2dJOJeTVY2
# https://t.co/pwKi5czj0i
# http://t.co/4qH21PHO3q
# http://t.co/oJTAacJ039
# https://t.co/HEl0mFdmn1
# https://t.co/DYsLEwQdHA
# http://t.co/rnPSzmNLM9
# http://t.co/r9aoptoEVf
# https://t.co/xscskSysEG
# https://t.co/7974o0xTJi
# https://t.co/4Thv9Kr5qG
# http://t.co/KaFxoDIZVs
# http://t.co/2eHKDSm1pv
# https://t.co/FSpHaFF8Yi https://t.co/2SW3PaMofZ
# https://t.co/kip4pRf7Bj
# http://t.co/rxHPpgdjrf
# http://t.co/lFkXT4jRVp
# https://t.co/n7oo0onHf3
#  https://t.co/InK1Pt8kPK
# 41!
# http://t.co/yB3RUQgn9Y
# http://fb.me/DIbzxSum
# https://t.co/X5W5aOP4qX
# http://t.co/o2bdzeVytZ http://t.co/k0QBS4a3HR
# https://t.co/dilYGdmh22
# https://t.co/8UKOBGqUFL
# https://t.co/geHLNVDjyw https://t.co/4tokE6CVGD
# http://t.co/jS13sWHb9r
# https://t.co/VNB59ITiuv
# http://t.co/OL5AnfAH http://t.co/DDXc2SzY
# http://t.co/PwrI3f0pwS
# http://t.co/K7RlRg0wU4 http://t.co/yS0dzS6g21
# http://t.co/CCX9NXGX55 http://t.co/jDMKeTOJnA
# https://t.co/Av9San1c6R
# https://t.co/BhuMuPut5v
# https://t.co/za2H0AmtEk
# http://fb.me/Llq2ciDe
# http://t.co/znEoN7uVIB
# http://t.co/2y8pzKDSPQ
# http://t.co/eLtBlAflyN
# .@TedNesi https://t.co/dI1ZnMMrS7
# http://t.co/M8j95oPV http://t.co/1J7hkyfv
# https://t.co/wzVIDESsNQ https://t.co/5k8uRuaxWz
# https://t.co/uLRdylHHBO
# https://t.co/E7P5hq6Ocr
# https://t.co/WXr5O7zri9
# https://t.co/FbeAJRWazX
# https://t.co/5uWWnTX5AU
# http://t.co/SeBQukVwte
# http://t.co/0VF66l7K http://t.co/JroDfl6W
# http://t.co/MDp37ht34U http://t.co/TjIi8pC8TM
# https://t.co/J89D99B3Si
# https://t.co/U7CgipQKMG
# https://t.co/mVJYL5pDaa
# http://t.co/yt7Irb8Xs0
# http://t.co/28XcjleE
# https://t.co/4YTnspShhD
# ???? https://t.co/an0m6AW9u1
# http://t.co/URZXfgLeQi
# http://www.wkok.com/1070_WKOK/Listen_live.htm
# http://t.co/Z13nLld64c... http://t.co/tYc7OistXn
# https://t.co/YnUWNydpnP
# https://t.co/TWtgbxPQqb
# https://t.co/Ye9APb1Xuv
# https://t.co/3S62qwuQ5K
# nan
# http://t.co/u4JfO7Ennd
# http://t.co/myOAaGMFP8
# http://t.co/CWMtpteIw4
# https://t.co/1IINCSiUy6
# https://t.co/JaafxH2HzD https://t.co/WvUf229kHL
# http://t.co/NKpKaee4s5
# https://t.co/p3CdzvBHy3
# https://t.co/vvAWdP7BQg
# https://t.co/zIEMNh9gZm
# https://t.co/yVgww2bQ3N
# https://t.co/gVM7uCOIP2
# http://t.co/A6muqoyg... http://t.co/b9gNleTy
# https://t.co/juw1ai9iLZ
# http://www.youtube.com/watch?v=2KJ7PMx0Idk http://fb.me/F8ZB2DhT
# https://t.co/uFcQ2FsIQq
# https://t.co/2movL3ipQV
# https://t.co/VvwZtZ5jqM
# https://t.co/8TmQGNQSHS
# http://fb.me/QctHDqkG
# http://homeland.house.gov/news/ny-daily-news-after-osama-bin-ladens-death-terrorists-still-targeting-mass-transit-s... http://fb.me/Wg0h33gF
# http://fb.me/12sFhFPeR
# http://tinyurl.com/ya93ea8 http://bit.ly/aaRehB
# https://t.co/9CbkSsKbJl
# http://fb.me/PZiK9QrY
# https://t.co/QtStm4bs21
# http://t.co/HZ8cu8dFjH http://t.co/ffXIrdkg8w
# https://t.co/nuyK2pU48V
# https://t.co/kRCFz0qKyd
# http://tinyurl.com/ctxchl
# https://t.co/wq6vS2nZO2
# http://www.google.com/hostednews/ap/article/ALeqM5jYRs9Uh1WAfkrHvZqjESuPxR2K6AD989HVTO0
# https://t.co/K9T7JWj3QH
# https://t.co/NAttREYuXr
# http://bit.ly/aNA8pN
# http://t.co/I0Vw84ye... http://t.co/vPVcltny
# https://t.co/U9oM18o8Cj
# https://t.co/3taO5UOBAv
# https://t.co/kSbiMWDerz
# https://t.co/LHD7VHPYvp
# http://t.co/KykRV5uu http://t.co/g8s4blL3
# https://t.co/EHLhsylU8d
# https://t.co/1xeFUnTZ6R http://t.co/oFRsFrZYUN
# https://t.co/H2mxJupGeJ
# http://t.co/yGJEHfUDKi
# http://online.wsj.com/article/SB10001424052748704436004576299571015982098.html http://fb.me/11Vav4QzI
# https://t.co/4fjrU9jtok
# .@Michael_CAFC https://t.co/kMbOeBaJka
# http://t.co/XBILnWZ3dA
# https://t.co/kN3V4orOxK
# https://t.co/tdgPjSepeo
# http://t.co/ToDj3lbeyT
# https://t.co/MIR0YqcdMR
# https://t.co/ly3DENZiMi
# https://t.co/IHOWYOLSl2
# https://t.co/Wqgv2VU7x5
# http://t.co/Nm0hfs98mg
# http://t.co/O9DEBZY87T http://t.co/i3ak6sFzcI
# http://t.co/INEAHkC0... http://t.co/9liTYMlT
# https://t.co/Ouc1qxzAjh
# https://t.co/r7FZcMuQEO
# http://t.co/rTABIeISrh
# http://t.co/YzU0TC4g3u http://t.co/bVNZXExrKq
# http://www.facebook.com/photo.php?pid=4307371&l=7e3600f898&id=23444159584
# http://t.co/WJxxG9ixPh
# https://t.co/gYDRbNPc0c
# http://t.co/T5RjeesT http://t.co/4aJWT9bE
#  https://t.co/RwVQ1HvmfS
# http://burrforsenate.com/response/
# https://t.co/47MlppUj36
# http://twitpic.com/2bv32f
# https://t.co/TjwgerC1Dt
# https://t.co/mP5la3wOug
# https://t.co/zun3thEZsY
# http://t.co/9AY5qQbX6K
# https://t.co/h59kDBwBva
# https://t.co/GmOrE9Qq5t
# https://t.co/yZLdPFR7TI
# http://t.co/izf8WNLKtB
# https://t.co/2Is8N7x4Mf
# https://t.co/sAvYpJcGDg
# https://t.co/9rZv6i1RoA https://t.co/FYcQN8oMxE
# https://t.co/PZj7ytBWVU
# https://t.co/OlEVgMExVj
# https://t.co/KK0BR1WQLV
# https://t.co/oTeyyp9roR
# https://t.co/oxvFgOUIZt
# https://t.co/XRN1DDMVqO
# https://t.co/UoEBOwMA3E
# http://t.co/5PzxzXBIWJ... http://t.co/0xyg77SVds
# https://t.co/V9NZX6ndUI
# https://t.co/iQtgu36pNg
# https://t.co/2FrAQu1xsy
# https://t.co/iup8rMv6cS
# http://t.co/OFvIryx8SM
# http://t.co/egSX9FDqi9 http://t.co/Pp7m3E3i4O
# https://t.co/efXVqPmdZa
# https://t.co/sXJVjXrQ6y
# http://t.co/07WM4NFm0U https://t.co/QclayzWvmN
# http://t.co/NMlh4kxuTu
# 3.141592653589793238462643383279502884197169399375105820974944592307816406286208998628034825342117067982148086513282306647093844609550582231
# https://t.co/vXjkCmIt40
# https://t.co/AeHcNMr2LH
# http://t.co/OFSPdiS4
# http://bit.ly/d18q7l
# http://t.co/9Y1k4Jsa http://t.co/9Quy9OpX
# http://t.co/vkrTORuqbg http://t.co/HpHNzSUXMx
# https://t.co/XTGaKrkO5Y
# http://t.co/34MGa0zY
# https://t.co/PFbm7bQR8D
# https://t.co/zoWNjEReKv
# http://www.youtube.com/watch?v=eLiIW42nPXo http://fb.me/DYxyv8tl
# https://t.co/P9o1pfaIjz
# https://t.co/v4ObTZz9o8
# http://t.co/5ADXeDqKXY
# https://t.co/aBHdlBC5Wt
# https://t.co/qXXj1FAmGM

# %%
print("Troll tweets size:", troll_tweet_data.shape)
print("Politician tweets size: ", pol_tweet_data.shape)
print("News tweets size:", news_tweet_data.shape)
# Out:
# Troll tweets size: (72964, 8)
# Politician tweets size:  (196525, 8)
# News tweets size: (41069, 9)

# %%
print("NAs:")
print("Troll:", troll_tweet_data.account_category.isna().sum())
print("Politician:", pol_tweet_data.account_category.isna().sum())
print("News:", news_tweet_data.account_category.isna().sum())
# Out:
# NAs:
# Troll: 0
# Politician: 0
# News: 0

# %%
troll_tweet_data = troll_tweet_data.sample(n=news_tweet_data.shape[0], random_state=42)
pol_tweet_data = pol_tweet_data.sample(n=news_tweet_data.shape[0], random_state=42)

# %%
combined_tweet_data = pd.concat([troll_tweet_data, pol_tweet_data, news_tweet_data], ignore_index=True, sort=False)

# %%
combined_tweet_data.to_csv("./datasets/combined_data.csv", sep=";", index=False)
